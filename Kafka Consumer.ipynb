# %%
from kafka import KafkaConsumer

# %%
consumer = KafkaConsumer('twitter')

# %%
for message in consumer:
    print (message)
# Out:
# ConsumerRecord(topic='twitter', partition=0, offset=865, timestamp=1614300810778, timestamp_type=0, key=None, value=b'{"created_at":"Fri Feb 26 00:53:25 +0000 2021","id":1365102636014403586,"id_str":"1365102636014403586","text":"RT @ezralevant: \\"The game\\" = more wars, I guess. https:\\/\\/t.co\\/LjGo9UMTyB","source":"\\u003ca href=\\"https:\\/\\/mobile.twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter Web App\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":4472647047,"id_str":"4472647047","name":"xurious","screen_name":"xuriousmusic","location":"United Kingdom","url":null,"description":"Music maker.","translator_type":"none","protected":false,"verified":false,"followers_count":8197,"friends_count":1141,"listed_count":51,"favourites_count":108950,"statuses_count":36668,"created_at":"Sun Dec 13 18:04:59 +0000 2015","utc_offset":null,
# ...
